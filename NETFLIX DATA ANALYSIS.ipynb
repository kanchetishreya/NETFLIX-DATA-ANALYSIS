# %%
import pandas as pd

# %%
net=pd.read_csv(r"C:\Users\nikhi\Downloads\Netflix.csv")
net
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
net.shape
# Out:
# (7789, 11)

# %%
net.size
# Out:
# 85679

# %%
#to get first 5 rows
net.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#to get last 5 rows
net.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
#to get each column name
net.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
#to get datatype of each column
net.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#to get details of dataset
net.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
#find if is there any duplicate values and if yes renmove the duplicate records
net[net.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
net.drop_duplicates(inplace= True)
net
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#is there null value present in any column then represent it with heat map
net.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(net.isnull())
# Out:
# <Axes: >

# %%
#for "House of Cards" what is the show id and who is the director of this show
net[net["Title"].isin(["House of Cards"])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#we can also use str.contains()
net[net["Title"].str.contains("House of Cards")]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#in which year highest number of the TV shows and Movies were released show them with bar graph
net.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#converting object to datetime
net['Date_N'] = pd.to_datetime(net['Release_Date'], errors='coerce')

# %%
net.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
net["Date_N"].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2137
# 2020.0    2009
# 2018.0    1661
# 2017.0    1201
# 2016.0     432
# 2021.0     117
# 2015.0      79
# 2014.0      24
# 2011.0      13
# 2013.0      10
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
#Find out in which year highest number of tv showws and movies got released
net["Date_N"].dt.year.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Date_N'>

# %%
#how many tv shows and movies are in the dataset show with bar graph
net.groupby("Category").Category.count()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
#to show the count of all unique values of any column in the from of bar graph
import seaborn as sns
sns.countplot(net["Category"])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
#show all the films that were released in year 2000
#we need to create a column that only contains year
net["Year"]=net["Date_N"].dt.year

# %%
net.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# Year                   float64
# dtype: object

# %%
#applying filter
net[(net["Year"]==2020.0)&(net["Category"]=="Movie")]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
#show all the titles of all tv shows that were released in India only
net[(net["Country"]=="India") & (net["Category"]=="TV Show")]["Title"]
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
#show top 10 Directors who gave the highest number of TV shows and Movies to Netflix
net["Director"].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Shannon Hartman            8
# Name: count, dtype: int64

# %%
#show all the records where "Category" is "Movie" and type is "Comedies" or Country is "United Kingdom".
k.
net[(net["Category"]=="Movie")&(net["Type"]=="Comedies")|(net["Country"]=="United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
#in how many movies Tom Cruise was cast
# we need to remove null values from cast 
net_new=net.dropna()

# %%
net_new[net_new["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
#what are the different ratings defined by netflix
net_new["Rating"].nunique()
# Out:
# 14

# %%
net_new["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
net_new["Rating"].value_counts()
# Out:
# Rating
# TV-MA       1668
# TV-14       1132
# R            654
# TV-PG        410
# PG-13        375
# PG           238
# TV-G          80
# TV-Y          71
# TV-Y7         69
# NR            62
# G             38
# UR             5
# TV-Y7-FV       3
# NC-17          2
# Name: count, dtype: int64

# %%
#how many Movies and tv shows got the "TV-14" Ratings in canada
net_new[(net_new["Rating"]=="TV-14") & (net_new["Country"]=="Canada")]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 1687   s1688  TV Show                         Degrassi: Next Class
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# ...

# %%
#how many tv shows/Movies got the "r" rating after year 2018
net_new[(net_new["Rating"]=="R")&(net_new["Year"]>2018)]
# Out:
#      Show_Id Category               Title                       Director  \
# 7         s8    Movie                 187                 Kevin Reynolds
# 14       s15    Movie                3022                     John Suits
# 65       s66    Movie             13 Sins                   Daniel Stamm
# 68       s69    Movie           14 Blades                     Daniel Lee
# 83       s84    Movie  20th Century Women                     Mike Mills
# ...      ...      ...                 ...                            ...
# 7659   s7658    Movie           Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie       Yes, God, Yes                    Karen Maine
# 7738   s7737    Movie         Young Adult                  Jason Reitman
# 7776   s7775    Movie              Zodiac                  David Fincher
# 7780   s7779    Movie          Zombieland                Ruben Fleischer
#
#                                                    Cast  \
# ...

# %%
#what is the maximum duration of a movie/show on netflix
net[["Minutes", "Unit"]]=net["Duration"].str.split(' ',expand=True)

# %%
net.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description     Date_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
net["Minutes"].max()
# Out:
# '99'

# %%
#which individual country has highest number of tv shows
net_tv=net_new[net_new["Category"]=="TV Show"]

# %%
net_tv.head(10)
# Out:
#     Show_Id Category                         Title  \
# 5        s6  TV Show                            46
# 132    s133  TV Show                     7 (Seven)
# 218    s219  TV Show               A Queen Is Born
# 260    s261  TV Show                      A.I.C.O.
# 276    s277  TV Show                  Abby Hatcher
# 322    s323  TV Show           Afronta! Facing It!
# 337    s338  TV Show              Age of Rebellion
# 426    s427  TV Show                  Almost Happy
# 531    s532  TV Show       Anitta: Made In Honório
# 578    s579  TV Show  Ari Shaffir: Double Negative
#
#                                   Director  \
# 5                              Serdar Akar
# 132                            Nizar Shafi
# 218                           Carla Barros
# 260                          Kazuya Murata
# 276                            Kyran Kelly
# 322                        Juliana Vicente
# 337                               Peter Ho
# 426                      Hernán Guerschuny
# ...

# %%
net_tv["Country"].max()
# Out:
# 'United States, Israel, Italy, South Africa'

# %%
net_tv["Country"].value_counts()
# Out:
# Country
# United States                                                    25
# United Kingdom                                                   18
# Japan                                                            10
# South Korea                                                       9
# Spain                                                             7
# Taiwan                                                            6
# India                                                             5
# Turkey                                                            5
# Brazil                                                            4
# Canada                                                            3
# France                                                            3
# Nigeria                                                           3
# Thailand                                                          3
# United States, Canada                                             2
# ...

# %%
#how can we sort dataset by year
net_new.sort_values(by = "Year")
# Out:
#      Show_Id Category                        Title                Director  \
# 7115   s7114    Movie         To and From New York    Sorin Dan Mihalcescu
# 5766   s5766    Movie                     Splatter               Joe Dante
# 3248   s3249    Movie      Just Another Love Story            Ole Bornedal
# 3840   s3841    Movie  Mad Ron's Prevues from Hell              Jim Monaco
# 5833   s5833    Movie               Strange Voices  Arthur Allan Seidelman
# ...      ...      ...                          ...                     ...
# 3237   s3238    Movie                Julie & Julia             Nora Ephron
# 3390   s3391    Movie                      Killers          Robert Luketic
# 6977   s6976    Movie                 The Vanished         Peter Facinelli
# 3062   s3063    Movie          Is Love Enough? Sir             Rohena Gera
# 7147   s7146    Movie  Tony Parker: The Final Shot           Florent Bodin
#
# ...

# %%
net_new.sort_values(by = "Year", ascending=False).head()
# Out:
#      Show_Id Category                        Title         Director  \
# 7571   s7570    Movie  What Would Sophia Loren Do?    Ross Kauffman
# 7572   s7571    Movie  What's Eating Gilbert Grape  Lasse Hallström
# 6771   s6770    Movie            The Polar Express  Robert Zemeckis
# 692     s693    Movie               Bad Grandpa .5    Jeff Tremaine
# 4269   s4270    Movie                          Mud     Jeff Nichols
#
#                                                    Cast        Country  \
# 7571        Nancy "Vincenza Careri" Kulik, Sophia Loren  United States
# 7572  Johnny Depp, Leonardo DiCaprio, Juliette Lewis...  United States
# 6771  Tom Hanks, Leslie Zemeckis, Eddie Deezen, Nona...  United States
# 692   Johnny Knoxville, Jackson Nicoll, Greg Harris,...  United States
# 4269  Matthew McConaughey, Reese Witherspoon, Tye Sh...  United States
#
#           Release_Date Rating Duration  \
# 7571  January 15, 2021  TV-14   32 min
# 7572   January 1, 2021  PG-13  118 min
# ...
